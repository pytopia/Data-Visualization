# %% [markdown]
# <img src="./images/banner.png" width="800">

# %% [markdown]
# # Introduction to Matplotlib

# %% [markdown]
# Welcome to our first lecture on Matplotlib! In this session, we'll dive into the world of data visualization using one of Python's most popular and powerful libraries.

# %% [markdown]
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python. It's often described as the "grandfather" of Python visualization libraries, and for good reason:
#
# - **Versatility**: Matplotlib can produce a wide array of high-quality figures, including line plots, scatter plots, bar charts, histograms, 3D plots, and much more.
#
# - **Customization**: It offers fine-grained control over every aspect of a plot, from colors and styles to axes and labels.
#
# - **Integration**: Matplotlib integrates well with NumPy and can be used in various Python environments, including Jupyter notebooks, web application servers, and graphical user interfaces.
#
# - **Publication-ready output**: The plots created with Matplotlib can be easily adjusted to meet publication standards.
#
# - **Community and ecosystem**: As one of the oldest and most widely-used plotting libraries in Python, Matplotlib has a large community, extensive documentation, and serves as the foundation for many other visualization libraries like Seaborn.

# %% [markdown]
# Matplotlib was created by John Hunter in 2003. His goal was to enable Python users to create publication-quality plots suitable for scientific research. The library was inspired by MATLAB's plotting capabilities, which is reflected in its name: "Matplotlib" is a play on "MATLAB plot".

# %% [markdown]
# Over the years, Matplotlib has evolved significantly, incorporating new features, improving performance, and adapting to the changing landscape of data science and scientific computing.

# %% [markdown]
# In the following sections, we'll learn how to install Matplotlib, understand its basic structure, and create our first plots. By the end of this lecture, you'll have a solid foundation to start creating your own data visualizations with Matplotlib.

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Installing and Importing Matplotlib](#toc1_)
#   - [Installation](#toc1_1_)
#   - [Importing Matplotlib](#toc1_2_)
#   - [Checking the Installation](#toc1_3_)
#   - [Backend Considerations](#toc1_4_)
#   - [A Simple Test Plot](#toc1_5_)
# - [The Matplotlib Object Hierarchy](#toc2_)
#   - [Figure](#toc2_1_)
#   - [Axes](#toc2_2_)
#   - [Axis](#toc2_3_)
#   - [Artist](#toc2_4_)
# - [Creating Your First Plot](#toc3_)
#   - [Basic Line Plot](#toc3_1_)
#   - [Multiple Lines](#toc3_2_)
#   - [Scatter Plot](#toc3_3_)
# - [Recap and Summary](#toc4_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_'></a>[Installing and Importing Matplotlib](#toc0_)

# %% [markdown]
# Before we can start creating visualizations, we need to make sure Matplotlib is installed and properly imported into our Python environment. Let's go through this process step by step.

# %% [markdown]
# ### <a id='toc1_1_'></a>[Installation](#toc0_)

# %% [markdown]
# If you haven't installed Matplotlib yet, you can easily do so using pip, Python's package installer. Open your terminal or command prompt and run:
#
# ```
# pip install matplotlib
# ```

# %% [markdown]
# For those using Anaconda, you can use conda to install Matplotlib:
#
# ```
# conda install matplotlib
# ```

# %% [markdown]
# ### <a id='toc1_2_'></a>[Importing Matplotlib](#toc0_)

# %% [markdown]
# Once installed, we need to import Matplotlib into our Python script or Jupyter notebook. The convention is to import the `pyplot` module, which provides a MATLAB-like plotting interface. Here's how we typically import it:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# We use the alias `plt` for convenience, as it's a widely adopted convention in the Python community.

# %% [markdown]
# ### <a id='toc1_3_'></a>[Checking the Installation](#toc0_)

# %% [markdown]
# To verify that Matplotlib is correctly installed and imported, we can check its version:

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.1'

# %% [markdown]
# This should output the version number of your Matplotlib installation.

# %% [markdown]
# ### <a id='toc1_4_'></a>[Backend Considerations](#toc0_)

# %% [markdown]
# In Matplotlib, a **backend** refers to the software layer that actually renders the plot. Think of it as the "engine" that turns your Python commands into a visual representation. Matplotlib uses two types of backends:
#
# 1. **Interactive backends**: These allow you to interact with the plot (zoom, pan, save, etc.) in a separate window. Examples include Qt5Agg and TkAgg.
#
# 2. **Non-interactive backends**: These are used to save plots to files without displaying them on screen. Examples include Agg for raster graphics and SVG for vector graphics.

# %% [markdown]
# Matplotlib can use various backends to render plots, and the choice of backend can depend on your specific needs and environment. For instance:
#
# - In scripts, you might use a non-interactive backend to save plots to files.
# - In desktop applications, you'd typically use an interactive backend.
# - In Jupyter notebooks, you often use the inline backend to display plots directly in the notebook.

# %% [markdown]
# You can set the backend using the following code:

# %%
import matplotlib
matplotlib.use('Agg')  # Example: setting to Agg backend

# %% [markdown]
# However, in Jupyter notebooks, it's common to use the inline backend, which you can set up with:

# %%
# %matplotlib inline

# %% [markdown]
# This magic command ensures that plots are rendered inline in the notebook, making them immediately visible after the code cell that creates them.

# %% [markdown]
# Understanding backends can be helpful when you need to switch between different plotting environments or when you're troubleshooting display issues. For most basic plotting tasks, you won't need to worry about backends, but it's good to know they exist and what they do.

# %% [markdown]
# ### <a id='toc1_5_'></a>[A Simple Test Plot](#toc0_)

# %% [markdown]
# To make sure everything is working correctly, let's create a simple plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("A Simple Sine Wave")
plt.show()

# %% [markdown]
# If you see a sine wave plot, congratulations! You've successfully installed and imported Matplotlib, and you're ready to start your data visualization journey.

# %% [markdown]
# In the next section, we'll delve deeper into the structure of Matplotlib and understand its object hierarchy, which is crucial for creating and customizing plots effectively.

# %% [markdown]
# ## <a id='toc2_'></a>[The Matplotlib Object Hierarchy](#toc0_)

# %% [markdown]
# Understanding Matplotlib's object hierarchy is crucial for creating and customizing plots effectively. Let's break down the main components:

# %% [markdown]
# <img src="./images/matplotlib-figure-anatomy.webp" width="600">

# %% [markdown]
# ### <a id='toc2_1_'></a>[Figure](#toc0_)

# %% [markdown]
# At the top of the hierarchy is the **Figure** object. Think of it as the entire window or page where your plot(s) will be drawn.
#
# - A figure can contain one or more axes (subplots).
# - It manages the canvas, overall figure size, and other global properties.

# %% [markdown]
# ### <a id='toc2_2_'></a>[Axes](#toc0_)

# %% [markdown]
# **Axes** are where the actual plotting happens. Each Axes object is a single plot.
#
# - A figure can have multiple axes.
# - Axes contain most of the plot elements: X and Y axes, data points, legends, etc.
# - When you call plotting methods like `plot()`, `scatter()`, or `hist()`, you're actually calling methods of the Axes object.

# %% [markdown]
# ### <a id='toc2_3_'></a>[Axis](#toc0_)

# %% [markdown]
# Each Axes has two (or three in 3D) **Axis** objects:
#
# - They handle the ticks and labels for the x and y (and z) axes.
# - You can customize properties like tick locations, label formatting, and axis limits through these objects.

# %% [markdown]
# ### <a id='toc2_4_'></a>[Artist](#toc0_)

# %% [markdown]
# Everything you see in a figure is an **Artist** object:
#
# - This includes Text, Line2D, collections, Axis, etc.
# - Artists handle drawing and layout within the figure.

# %% [markdown]
# Here's a simple diagram to visualize this hierarchy:
#
# ```
# Figure
# └── Axes
#     ├── Axis (X-axis, Y-axis)
#     └── Artists (lines, text, etc.)
# ```

# %% [markdown]
# Let's see this hierarchy in action with a simple example:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and an axes
fig, ax = plt.subplots()

# Generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot the data on the axes
ax.plot(x, y)

# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('A Simple Sine Wave')
# Out:
# Text(0.5, 1.0, 'A Simple Sine Wave')

# %% [markdown]
# In this example:
# - We create a `Figure` and an `Axes` object with `plt.subplots()`.
# - We use the `Axes` object (`ax`) to plot our data and set labels.
# - The `plot()` method creates a `Line2D` artist to represent our data.
# - `plt.show()` displays the entire figure.

# %% [markdown]
# Understanding this hierarchy will help you navigate Matplotlib's API more effectively and give you greater control over your visualizations. As we progress through the course, you'll see how to manipulate these different objects to create complex and customized plots.

# %% [markdown]
# ## <a id='toc3_'></a>[Creating Your First Plot](#toc0_)

# %% [markdown]
# Now that we understand the basics of Matplotlib's structure, let's dive in and create our first plot. We'll start with a simple line plot, which is one of the most common types of visualizations.

# %% [markdown]
# ### <a id='toc3_1_'></a>[Basic Line Plot](#toc0_)

# %% [markdown]
# Let's create a plot of a simple mathematical function, y = x^2.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
x = np.linspace(-5, 5, 100)
y = x**2

# Create the plot
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(x, y)

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Y = X^2')

# Jupyter notebook inline backend does not require plt.show()
# Out:
# Text(0.5, 1.0, 'Y = X^2')

# %%
# Display the plot using fig object
fig

# %% [markdown]
# In this example:
# 1. We use `numpy` to generate our x and y data.
# 2. `plt.subplots()` creates a figure and axes object.
# 3. We use the `plot()` method of the axes object to create our line.
# 4. We add labels and a title using axes methods.

# %% [markdown]
# ### <a id='toc3_2_'></a>[Multiple Lines](#toc0_)

# %% [markdown]
# Now, let's plot multiple lines on the same axes:

# %%
# Generate data
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create the plot
fig, ax = plt.subplots(figsize=(6, 3))
ax.plot(x, y1, label='sin(x)')
ax.plot(x, y2, label='cos(x)')

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Sine and Cosine Functions')

# Add a legend
ax.legend()

# %% [markdown]
# Here, we've added:
# - Two different lines on the same axes
# - A legend to distinguish between the lines

# %% [markdown]
# ### <a id='toc3_3_'></a>[Scatter Plot](#toc0_)

# %% [markdown]
# Let's create a scatter plot to show how to visualize discrete data points:

# %%
# Generate random data
np.random.seed(42)
x = np.random.rand(50)
y = np.random.rand(50)

# Create the plot
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(x, y, color='red', alpha=0.5)

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Random Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Random Scatter Plot')

# %% [markdown]
# In this example:
# - We use `np.random.rand()` to generate random data.
# - The `scatter()` method is used instead of `plot()`.
# - We've added some basic customization with `color` and `alpha` (transparency) parameters.

# %% [markdown]
# These examples demonstrate the basics of creating plots with Matplotlib. As you can see, with just a few lines of code, you can create informative and visually appealing plots. In the upcoming sections, we'll dive deeper into customizing these plots and exploring more complex visualizations.

# %% [markdown]
# ## <a id='toc4_'></a>[Recap and Summary](#toc0_)

# %% [markdown]
# In this introductory lecture on Matplotlib, we've covered several fundamental concepts and practices. Let's recap the key points:
#
# 1. **What is Matplotlib?**
#    - Matplotlib is a versatile Python library for creating static, animated, and interactive visualizations.
#    - It offers extensive customization options and integrates well with NumPy and other Python libraries.
#
# 2. **Matplotlib Object Hierarchy**
#    - We explored the main components: Figure, Axes, Axis, and Artists.
#    - Understanding this hierarchy is crucial for effective plot creation and customization.
#
# 3. **Creating Basic Plots**
#    - We created our first line plot, demonstrating the basic structure of a Matplotlib script.
#    - We explored how to create multiple lines on the same axes.
#    - We also created a scatter plot, showing how to visualize discrete data points.

# %% [markdown]
# The basic workflow in Matplotlib typically involves:
#   1. Importing the library
#   2. Preparing the data
#   3. Creating a figure and axes
#   4. Plotting the data
#   5. Customizing the plot (labels, titles, etc.)

# %% [markdown]
# In the upcoming lectures, we'll dive deeper into:
# - More advanced plot types
# - Extensive customization options
# - Handling multiple subplots
# - Working with different data types and structures

# %% [markdown]
# Remember, the key to mastering Matplotlib is practice. Experiment with different plot types and customizations to become more comfortable with the library's capabilities.
